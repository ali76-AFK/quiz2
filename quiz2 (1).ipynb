# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/content/stuff.JPG')#the path of the imported image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (9, 9), 0)
canny = cv2.Canny(blur, 20, 190, 3)#these parameters are to be controlled to allow for filtering
dilated = cv2.dilate(canny, (1, 1), iterations=0)
# applying morphilogical Operations 
dilation = cv2.dilate(canny , (2,2), iterations=4)       # Dilation Morphological Method
closing = cv2.morphologyEx(canny, cv2.MORPH_CLOSE,(4,4)) # Closing Morphological Method
# Create contours for the Closing Morphological Method
(contour1, hierarchy) = cv2.findContours(closing.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
rgb1 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb1, contour1, -1, (0, 255, 0), 2)
print("Counting using closing method = ", len(contour1))


print("lego in the image : ", len(cnt))
plt.imshow(dilation, cmap="gray")
# Out:
# Counting using closing method =  20
# lego in the image :  23

# %% [markdown]
# Flow chart =====>
# Load the image into the system => Pre-process the image, if necessary (e.g., convert to grayscale, apply filters to enhance contrast) => Define the morphological operation to be performed (e.g., erosion, dilation, closing) => Select the structuring element to be used for the operation (e.g., a square, a diamond, a disk) => Apply the morphological operation to the image using the chosen structuring element.
# If desired, apply additional morphological operations to the image => Post-process the image, if necessary (e.g., thresholding, edge detection) => Save the processed image or display it to the user.
